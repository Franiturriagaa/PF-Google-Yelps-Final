# %%
import pandas as pd

# %%
df = pd.read_parquet('../../Data/user-001.parquet')

# %%
df
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %%
# En la nube, estes dataframe es extraido desde Big Query, ya transformado
df2 = pd.read_json('../../Data/tip.json', lines= True, nrows=100000)

# %%
df2
# Out:
#                       user_id             business_id  \
# 0      AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1      NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2      -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3      FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4      ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                       ...                     ...
# 99995  bKvJxHeOAASeruYRlvgx5g  Zi-F-YvyVOK0k5QD7lrLOg
# 99996  7cPYV4VCuO5IU4hMxzA3YA  iMTjejk6apJKzCukZnDw5A
# 99997  fCvMnJU1Z-XhAjKg99wK3Q  Xwp9dHOS975h0EWmlEC2tw
# 99998  fRTGhUovTkqmDH8mxigP3Q  1fK1voue0RXNMXVBagvafA
# 99999  QaCbRxUMAcTJl5YwA6inDA  F2C5ENuY8CXfgoW-gAMdDA
#
#                                                     text                date  \
# 0                         Avengers time with the ladies. 2012-05-18 02:17:21
# 1      They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2                 It's open even when you think it isn't 2013-08-18 00:56:08
# ...

# %%
# En la nube, estes dataframe es extraido desde Big Query, ya transformado
df3 = pd.read_json('../../Data/review-002.json', lines= True, nrows=100000)

# %%
df3
# Out:
#                     review_id                 user_id             business_id  \
# 0      KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1      BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2      saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3      AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4      Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                       ...                     ...                     ...
# 99995  pAEbIxvr6ebx2bHc1XvguA  SMH5CeiLvKx61lKwtLZ_PA  lV0k3BnslFRkuWD_kbKd0Q
# 99996  xH1AoE-4nf2ECGQJRjO4_g  2clTdtp-BjphxLjN83CpUA  G0xz3kyRhRi6oZl7KfR0pA
# 99997  GatIbXTz-WDru5emONUSIg  MRrN6DH3QGCFcDv5RENYVg  C4lZdhasjZVQyDlOiXY1sA
# 99998  6NfkodAdhvI89xONXuBC3A  rnNQzeKJbvqVCsYsL10mkQ  dChRGpit9fM_kZK5pafNyA
# 99999  sJ1BMq7lkKgOWEFx3n6ZRw  _BcWyKQL16ndpBdggh2kNA  hMcgO98QaOFmQVTfCUeGzw
#
# ...

# %%
# Utilizamos solo los usuarios que estan en nuestros otros datasets
df =df[(df['user_id'].isin(df2['user_id'])) | (df['user_id'].isin(df3['user_id']))]

# %%
df
# Out:
#                         user_id         name  review_count  \
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 5        q_QQ5kBBwlCcbL1s4NVK3g         Jane          1221
# 7        E9kcWJdJUHuTKfQurPljwA         Mike           358
# 9        AUi8MPWJ0mLkMfwbui27lg         John           109
# 12       vVukUtqoLF5BvH_VtQFNoA     Charlene            37
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 1        2009-01-25 04:35:42   43091  13066  27281
# 5        2005-03-14 20:26:35   14953   9940  11211
# 7        2008-12-11 22:11:56     399    102    143
# ...

# %%
df.dtypes
# Out:
# user_id                object
# name                   object
# review_count            int64
# yelping_since          object
# useful                  int64
# funny                   int64
# cool                    int64
# elite                  object
# friends                object
# fans                    int64
# average_stars         float64
# compliment_hot          int64
# compliment_more         int64
# compliment_profile      int64
# compliment_cute         int64
# compliment_list         int64
# compliment_note         int64
# compliment_plain        int64
# compliment_cool         int64
# compliment_funny        int64
# compliment_writer       int64
# compliment_photos       int64
# dtype: object

# %%
#Eliminamos las columnas no necesarias
df.drop(columns={'elite', 'friends', 'compliment_hot', 'compliment_more', 'compliment_profile', 'compliment_cute', 'compliment_list','compliment_note','compliment_plain','compliment_cool',
                 'compliment_funny','compliment_writer','compliment_photos'}, inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16112\1225444284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns={'elite', 'friends', 'compliment_hot', 'compliment_more', 'compliment_profile', 'compliment_cute', 'compliment_list','compliment_note','compliment_plain','compliment_cool',

# %%
df.dtypes
# Out:
# user_id           object
# name              object
# review_count       int64
# yelping_since     object
# useful             int64
# funny              int64
# cool               int64
# fans               int64
# average_stars    float64
# dtype: object

# %%
df['yelping_since']= pd.to_datetime(df['yelping_since'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16112\2138437479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yelping_since']= pd.to_datetime(df['yelping_since'])

# %%
df.dtypes
# Out:
# user_id                  object
# name                     object
# review_count              int64
# yelping_since    datetime64[ns]
# useful                    int64
# funny                     int64
# cool                      int64
# fans                      int64
# average_stars           float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('../../Data/business.pkl')

# %%
df=df.loc[:, ~df.columns.duplicated()]

# %%
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
df = df[(df['city'] =='Philadelphia')]

# %%
df
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 28      QdN72BWoyFypdGJhhI5r7g                              Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q                     DeSandro on Main
# ...                        ...                                  ...
# 150320  wPAaAbFbq5wfLfW0gnYU7g                             Intermix
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address          city state postal_code  \
# 3                        935 Race St  Philadelphia    CA       19107
# ...

# %%
df.drop(columns={'is_open', 'attributes', 'hours'}, inplace=True)

# %%
df['categories'] = df['categories'].str.split(',\s*')

# %%
df.dropna(subset=['categories'], inplace=True)

# %%
main_categories_set = {'Restaurants', 'Shopping', 'Bars', 'Beauty & Spas', 'Home Service', 'Health & Medical','Food','Home Services','Automotive', 'Local Services', 'Active Life', 'Hotels & Travel', 'Pets', 'Arts & Entertainment'}

def get_main_category(categories):
    for category in categories:
        if category in main_categories_set:
            categories.remove(category)  
            return category, categories  
    return None, categories

# %%
df[['main category', 'categories']] = df.apply(lambda row: pd.Series(get_main_category(row['categories'])), axis=1)

# %%
df
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 28      QdN72BWoyFypdGJhhI5r7g                              Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q                     DeSandro on Main
# ...                        ...                                  ...
# 150320  wPAaAbFbq5wfLfW0gnYU7g                             Intermix
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address          city state postal_code  \
# 3                        935 Race St  Philadelphia    CA       19107
# ...

# %%
df['main category'].isnull().sum()
# Out:
# 466

# %%
df_test = df[(df['main category'].isnull())]

# %%
df_exploded = df_test.explode('categories')

# %%
category_counts = df_exploded['categories'].value_counts()

# %%
top_categories   = category_counts.head(20)

# %%
plt.figure(figsize=(14, 8))

top_categories.plot(kind='bar', color='skyblue')

plt.xlabel('Categoria')
plt.ylabel('Cantidad')
plt.title('Top 20 Categorias mas comunes')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Restaurant, Shopping, Nightlife, Beauty & Spas, Bars, Home Service, Health & Medical

# %%
category_counts = df['main category'].value_counts()

# %%
plt.figure(figsize=(14, 8))

category_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Categoria')
plt.ylabel('Cantidad')
plt.title('Top 20 Categorias mas comunes')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
